# %%
import pandas as pd
import torch
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from pyomo.environ import *
import pyomo.environ as pe
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
def silu_fn(z):
    
    return z / (1 + np.exp(-z))
dtype = torch.get_default_dtype()

# %%
df = pd.read_csv('data.csv', header=1)
X = df.drop(columns=['thr','te','power'])
scaler_input = MinMaxScaler()
train_input_scaled = scaler_input.fit_transform(X)

# %%
class Net(torch.nn.Module):
    def __init__(self, n_feature, n_hidden, n_output, activation_fn=nn.ReLU, activation_scale=1.0):
        super(Net, self).__init__()
        self.hidden = nn.Linear(n_feature, n_hidden)   
        self.predict = nn.Linear(n_hidden, n_output)   
        self.activation_fn = activation_fn()           
        

    def forward(self, x):
        x = self.activation_fn(self.hidden(x))  
        x = self.predict(x)                                             
        return x

# %% [markdown]
# # THR Model

# %%
checkpoint = torch.load(f"thr_ext_model.pth")
params1 = checkpoint['params']
model_lower = Net(
    n_feature=9,
    n_hidden=10,
    n_output=1,
    activation_fn=nn.SiLU,)
model_lower.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
state_dict_lower = model_lower.state_dict()
W1_lower = state_dict_lower['hidden.weight'].numpy()
b1_lower = state_dict_lower['hidden.bias'].numpy()
W2_lower = state_dict_lower['predict.weight'].numpy()
b2_lower = state_dict_lower['predict.bias'].numpy()

# %% [markdown]
# # Power Model

# %%
checkpoint = torch.load(f"power_ext_model.pth")
params1 = checkpoint['params']
model_upper = Net(
    n_feature=9,
    n_hidden=31,
    n_output=1,
    activation_fn=nn.SiLU
    )
model_upper.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
state_dict_upper = model_upper.state_dict()
W1_upper = state_dict_upper['hidden.weight'].numpy()
b1_upper = state_dict_upper['hidden.bias'].numpy()
W2_upper = state_dict_upper['predict.weight'].numpy()
b2_upper = state_dict_upper['predict.bias'].numpy()

# %%
train_input_scaled_df=pd.DataFrame(train_input_scaled, columns=X.columns)

# %% [markdown]
# # Thermal Efficiency

# %%
checkpoint = torch.load(f"te_ext_model.pth")
params1 = checkpoint['params']
model_te = Net(
    n_feature=9,
    n_hidden=22,
    n_output=1,
    activation_fn=nn.SiLU
    )
model_te.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
state_dict_te = model_te.state_dict()
W1_te = state_dict_te['hidden.weight'].numpy()
b1_te = state_dict_te['hidden.bias'].numpy()
W2_te = state_dict_te['predict.weight'].numpy()
b2_te = state_dict_te['predict.bias'].numpy()

# %%
pd.DataFrame(train_input_scaled, columns=X.columns)
# Out:
#           cdp      gffr       fgt        at        ap        ah     phgot  \
# 0    0.483485  0.510675  0.510511  0.380845  0.676741  0.752338  0.657962
# 1    0.468376  0.548053  0.588242  0.400958  0.684187  0.741559  0.427813
# 2    0.488951  0.572813  0.591472  0.381426  0.744306  0.750910  0.137413
# 3    0.160401  0.183482  0.767659  0.430221  0.796978  0.702303  0.451135
# 4    0.149450  0.199031  0.753829  0.417441  0.691743  0.726842  0.564557
# ..        ...       ...       ...       ...       ...       ...       ...
# 485  0.270590  0.344896  0.743605  0.250436  0.721748  0.564406  0.415818
# 486  0.269046  0.351056  0.773643  0.215074  0.759417  0.609655  0.465883
# 487  0.262765  0.346630  0.672056  0.222408  0.766864  0.580331  0.444016
# 488  0.269843  0.338855  0.758624  0.221173  0.759417  0.612997  0.478153
# 489  0.262794  0.330423  0.715370  0.222989  0.736859  0.602344  0.444370
#
#           cdt     fgext
# 0    0.363868  0.793780
# 1    0.351192  0.816933
# 2    0.389613  0.886413
# 3    0.169066  0.932741
# 4    0.141682  0.932741
# ..        ...       ...
# 485  0.205054  0.991321
# 486  0.200233  0.991321
# 487  0.196096  0.991321
# 488  0.205555  0.991321
# 489  0.186673  0.991321
#
# [490 rows x 9 columns]

# %% [markdown]
# # Model Definition

# %%
model = ConcreteModel()
lower_bounds = [0.0,0.0,0.0,  0.425, 0.595, 0.495, 0.0,0.0,0.0]  # Lower bounds for indices 0, 1, 2
upper_bounds = [ 1.8, 1.8, 1.8,  0.430, 0.61, 0.505, 1.8, 1.8, 1.8]   # Upper bounds for indices 0, 1, 2

def variable_bounds(model, i):
    return (lower_bounds[i], upper_bounds[i])

model.x = Var(RangeSet(0, train_input_scaled.shape[1]-1), bounds=variable_bounds)

# %%
def mahalanobis_constraint(train_input_scaled,tolerance, factor = 1):
    mu = np.mean(train_input_scaled, axis=0)
    cov = np.cov(train_input_scaled, rowvar=False)
    inv_cov = np.linalg.pinv(cov)
    centered_data = train_input_scaled - mu
    D_M = np.sqrt(np.einsum('...i,ij,...j->...', centered_data, inv_cov, centered_data))
    return mu, inv_cov, np.percentile(D_M, tolerance) * factor

# %%
def add_upper_mahalanobis_constraint(model, train_input_scaled, tolerance, factor):
    mu, inv_cov, delta=mahalanobis_constraint(train_input_scaled, tolerance,factor)

    centered = [model.x[index] - mu[index] for index in range(train_input_scaled.shape[1])]

    quadratic_form = sum(centered[i] * inv_cov[i,j] * centered[j] for i in range(train_input_scaled.shape[1]) for j in range(train_input_scaled.shape[1]))
    
    setattr(model,'mahalanobis_constraint',Constraint(rule=delta-quadratic_form**0.5  >= 0))

# %%
def thr(model):
    total = b2_lower[0]
    for j in range(W1_lower.shape[0]):
        sum_in = b1_lower[j]
        for i in range(W1_lower.shape[1]):
            sum_in += W1_lower[j, i] * model.x[i]
        activated = sum_in / (1 + pe.exp(-sum_in))
        total += W2_lower[0, j] * activated
    return total

# %%
def power(model):
    total = b2_upper[0]
    for j in range(W1_upper.shape[0]):
        sum_in = b1_upper[j]
        for i in range(W1_upper.shape[1]):
            sum_in += W1_upper[j, i] * model.x[i]
        activated = sum_in / (1 + pe.exp(-sum_in))
        total += W2_upper[0, j] * activated
    return total

# %%
def te(model):
    total = b2_te[0]
    for j in range(W1_te.shape[0]):
        sum_in = b1_te[j]
        for i in range(W1_te.shape[1]):
            sum_in += W1_te[j, i] * model.x[i]
        activated = sum_in / (1 + pe.exp(-sum_in))
        total += W2_te[0, j] * activated
    return total

# %%
tolerance =60 # 40 for 385 MW, 45 for 390 MW AND 60 for 395 MW
factor = 1.0
add_upper_mahalanobis_constraint(model, train_input_scaled, tolerance, factor)

# %% [markdown]
# # Set Value of Power

# %%
scaler_input1 = MinMaxScaler()
train_label_scaled = scaler_input1.fit_transform(df['power'].values.reshape(-1, 1))
scaler_input2 = MinMaxScaler()
train_label_scaled = scaler_input2.fit_transform(df['thr'].values.reshape(-1, 1))
scaler_input3 = MinMaxScaler()
train_label_scaled = scaler_input3.fit_transform(df['te'].values.reshape(-1, 1))

# %%
current_value = 395
current_value_s = scaler_input1.transform([[current_value]])[0][0]
current_value
# Out:
# 395

# %%
def power_constraint (model): return (power(model)-current_value_s)**2 == 1e-10

model.power_constraint = Constraint(rule=power_constraint)

# %%
def objectives(model):
    thr_value = thr(model)
    te_value = te(model)
    #return (power(model)-current_value_s)**2 
    return (thr_value) - (te_value)
model.objectives = Objective(expr=objectives, sense=minimize)

# %%
solver = SolverFactory('gams:SNOPT')
#}

# %%
val=pd.read_csv('val.csv',header=1)
extra_1=pd.read_csv('extra.csv')
extra = pd.concat([val, extra_1],axis=0)
val_1=extra.drop(columns=['thr','te','power'])
vals=scaler_input.transform(val_1)

# %%
best_values = []
thr_sol = []
power_sol = []
TE_sol=[]

for x0 in vals[:50]:
    initial_values = list(np.clip(x0, 0, 1))
    for i in range(x0.shape[0]):
        model.x[i] = initial_values[i]

    results = solver.solve(model, tee=  True)

    optimal_scaled = [model.x[i]() for i in range(x0.shape[0])]
    optimal_real = scaler_input.inverse_transform([optimal_scaled])[0]
    best_values.append(optimal_real)
    thr_sol.append(thr(model)())
    power_sol.append(power(model)())
    TE_sol.append(te(model)())
# Out:
# WARNING (W1002): Setting Var 'x[3]' to a numeric value `0.3655968632006972`
# outside the bounds (0.425, 0.43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[4]' to a numeric value `0.8195356986421274`
# outside the bounds (0.595, 0.61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[5]' to a numeric value `0.771008535207732`
# outside the bounds (0.495, 0.505).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# --- Job model.gms Start 06/25/25 14:54:53 38.2.1 96226ea8 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\38\gmsprmNT.txt
#     C:\Users\Waqar\OneDrive - University College London\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     Input C:\Users\Waqar\AppData\Local\Temp\tmp8kolog4k\model.gms
#     Output C:\Users\Waqar\AppData\Local\Temp\tmp8kolog4k\output.lst
#     ScrDir C:\Users\Waqar\AppData\Local\Temp\tmp8kolog4k\225a\
#     SysDir C:\GAMS\38\
#     CurDir C:\Users\Waqar\AppData\Local\Temp\tmp8kolog4k\
#     LogOption 3
# Licensee: Large MUD - 20 User License                    S220119|0002AN-GEN
#           University College London, Dep. of Chemical Engineering    DC2250
#           C:\GAMS\38\gamslice.txt
#           License Admin: Lazaros Papageorgiou, l.papageorgiou@ucl.ac.uk
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 38.2.1   Copyright (C) 1987-2022 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(122) 2 Mb
# --- Starting execution: elapsed 0:00:00.021
# --- model.gms(55) 3 Mb
# --- Generating NLP model GAMS_MODEL
# --- model.gms(56) 5 Mb
# ---   3 rows  10 columns  28 non-zeroes
# ---   3,225 nl-code  27 nl-non-zeroes
# --- model.gms(56) 3 Mb
# --- Executing SNOPT (Solvelink=5): elapsed 0:00:00.025
#
# SNOPT            38.2.1 96226ea8 Feb 19, 2022          WEI x86 64bit/MS Window
#
#
#  ==============================
#  S N O P T  7.7.7    (Feb 2021)
#  ==============================
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  Nonlinear constraints       2     Linear constraints       1
#  Nonlinear variables         9     Linear variables         0
#  Jacobian  variables         9     Objective variables      9
#  Total constraints           3     Total variables          9
#  The user has defined      18   out of      18   constraint gradients.
#  The user has defined       9   out of       9   objective  gradients.
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     64      1  3.5E-01    128 (5.3E-07) 7.2E-06 -9.4221238E-01      4 6.0E+07
#     65      1  3.6E-01    130 (3.6E-07) 5.8E-06 -9.4220814E-01      4 9.6E+07
#     66      1  3.8E-01    132 (2.4E-07) 4.6E-06 -9.4220506E-01      4 1.5E+08
#     67      1  4.1E-01    134 (1.5E-07) 3.5E-06 -9.4220308E-01      4 2.4E+08
#     68      1  1.0E+00    135 (3.8E-08)(8.2E-07)-9.4220147E-01      4 3.6E+08
#  SNOPTC EXIT   0 -- finished successfully
#  SNOPTC INFO   1 -- optimality conditions satisfied
#
#  Problem name                 GAMS_MOD
#  No. of iterations                  89   Objective           -9.4220496807E-01
#  No. of major iterations            68   Linear    obj. term  6.9410897791E-02
#  Penalty parameter           3.649E+08   Nonlinear obj. term -1.0116158659E+00
#  User function calls (total)       135
#  No. of superbasics                  4   No. of basic nonlinears             2
#  No. of degenerate steps             0   Percentage                       0.00
#  Max x                       2 1.1E+00   Max pi                      2 1.9E+05
#  Max Primal infeas          10 4.1E-08   Max Dual infeas             1 2.0E-01
#  Nonlinear constraint violn    4.1E-08
#
#  Solution not printed
#  Time for solving problem                       0.01 seconds
#  Time for constraint functions                  0.00 seconds
#  Time for objective function                    0.00 seconds
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:00.093
# --- model.gms(122) 3 Mb
# --- Putfile results C:\Users\Waqar\AppData\Local\Temp\tmp8kolog4k\results.dat
# --- Putfile statresults C:\Users\Waqar\AppData\Local\Temp\tmp8kolog4k\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 06/25/25 14:54:53 elapsed 0:00:00.096
# WARNING (W1002): Setting Var 'x[3]' to a numeric value `0.38207958176009305`
# outside the bounds (0.425, 0.43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[4]' to a numeric value `0.8270915462111361`
# outside the bounds (0.595, 0.61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[5]' to a numeric value `0.76335195180118`
# outside the bounds (0.495, 0.505).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# --- Job model.gms Start 06/25/25 14:54:54 38.2.1 96226ea8 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\38\gmsprmNT.txt
#     C:\Users\Waqar\OneDrive - University College London\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     Input C:\Users\Waqar\AppData\Local\Temp\tmpsh3xlh68\model.gms
#     Output C:\Users\Waqar\AppData\Local\Temp\tmpsh3xlh68\output.lst
#     ScrDir C:\Users\Waqar\AppData\Local\Temp\tmpsh3xlh68\225a\
#     SysDir C:\GAMS\38\
#     CurDir C:\Users\Waqar\AppData\Local\Temp\tmpsh3xlh68\
#     LogOption 3
# Licensee: Large MUD - 20 User License                    S220119|0002AN-GEN
#           University College London, Dep. of Chemical Engineering    DC2250
#           C:\GAMS\38\gamslice.txt
#           License Admin: Lazaros Papageorgiou, l.papageorgiou@ucl.ac.uk
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 38.2.1   Copyright (C) 1987-2022 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(122) 2 Mb
# --- Starting execution: elapsed 0:00:00.022
# --- model.gms(55) 3 Mb
# --- Generating NLP model GAMS_MODEL
# --- model.gms(56) 5 Mb
# ---   3 rows  10 columns  28 non-zeroes
# ---   3,225 nl-code  27 nl-non-zeroes
# --- model.gms(56) 3 Mb
# --- Executing SNOPT (Solvelink=5): elapsed 0:00:00.028
#
# SNOPT            38.2.1 96226ea8 Feb 19, 2022          WEI x86 64bit/MS Window
#
#
#  ==============================
#  S N O P T  7.7.7    (Feb 2021)
#  ==============================
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  Nonlinear constraints       2     Linear constraints       1
#  Nonlinear variables         9     Linear variables         0
#  Jacobian  variables         9     Objective variables      9
#  Total constraints           3     Total variables          9
#  The user has defined      18   out of      18   constraint gradients.
#  The user has defined       9   out of       9   objective  gradients.
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     60      1  2.3E-01    118  3.3E-06  2.6E-05 -9.4228302E-01      4 7.4E+06
#     61      1  2.3E-01    120  2.7E-06  2.3E-05 -9.4227010E-01      4 1.0E+07
#     62      1  2.2E-01    122  2.2E-06  2.0E-05 -9.4225911E-01      4 1.3E+07
#     63      1  2.2E-01    124  1.8E-06  1.8E-05 -9.4224961E-01      4 1.8E+07
#     64      1  2.3E-01    126  1.5E-06  1.6E-05 -9.4224132E-01      4 2.3E+07
#     65      1  2.4E-01    128  1.2E-06  1.4E-05 -9.4223399E-01      4 3.1E+07
#     66      1  2.5E-01    130 (9.2E-07) 1.2E-05 -9.4222742E-01      4 4.2E+07
#     67      1  2.6E-01    132 (7.2E-07) 1.1E-05 -9.4222164E-01      4 5.8E+07
#     68      1  2.7E-01    134 (5.5E-07) 9.2E-06 -9.4221652E-01      4 8.1E+07
#     69      1  2.9E-01    136 (4.1E-07) 7.8E-06 -9.4221226E-01      4 1.1E+08
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     70      1  3.0E-01    138 (3.1E-07) 6.5E-06 -9.4220869E-01      4 1.6E+08
#     71      1  3.1E-01    140 (2.3E-07) 5.4E-06 -9.4220599E-01      4 2.3E+08
#     72      1  3.2E-01    142 (1.6E-07) 4.4E-06 -9.4220394E-01      4 3.3E+08
#     73      1  3.5E-01    144 (1.1E-07) 3.5E-06 -9.4220262E-01      4 4.5E+08
#     74      1  3.5E-01    146 (8.0E-08) 2.7E-06 -9.4220179E-01      4 6.1E+08
#     75      1  4.0E-01    148 (5.2E-08)(2.0E-06)-9.4220140E-01      4 7.9E+08
#  SNOPTC EXIT   0 -- finished successfully
#  SNOPTC INFO   1 -- optimality conditions satisfied
#
#  Problem name                 GAMS_MOD
#  No. of iterations                  89   Objective           -9.4221101570E-01
#  No. of major iterations            75   Linear    obj. term  6.9410897791E-02
#  Penalty parameter           7.900E+08   Nonlinear obj. term -1.0116219135E+00
#  User function calls (total)       148
#  No. of superbasics                  4   No. of basic nonlinears             2
#  No. of degenerate steps             0   Percentage                       0.00
#  Max x                       2 1.1E+00   Max pi                      2 1.8E+05
#  Max Primal infeas          10 5.5E-08   Max Dual infeas             8 7.6E-01
#  Nonlinear constraint violn    5.5E-08
#
#  Solution not printed
#  Time for solving problem                       0.01 seconds
#  Time for constraint functions                  0.00 seconds
#  Time for objective function                    0.00 seconds
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:00.055
# --- model.gms(122) 3 Mb
# --- Putfile results C:\Users\Waqar\AppData\Local\Temp\tmpsh3xlh68\results.dat
# --- Putfile statresults C:\Users\Waqar\AppData\Local\Temp\tmpsh3xlh68\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 06/25/25 14:54:54 elapsed 0:00:00.059
# WARNING (W1002): Setting Var 'x[3]' to a numeric value `0.3753267499273889`
# outside the bounds (0.425, 0.43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[4]' to a numeric value `0.7217477003942179`
# outside the bounds (0.595, 0.61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[5]' to a numeric value `0.7667095519015941`
# outside the bounds (0.495, 0.505).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# --- Job model.gms Start 06/25/25 14:54:54 38.2.1 96226ea8 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\38\gmsprmNT.txt
#     C:\Users\Waqar\OneDrive - University College London\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     Input C:\Users\Waqar\AppData\Local\Temp\tmpvgk41uma\model.gms
#     Output C:\Users\Waqar\AppData\Local\Temp\tmpvgk41uma\output.lst
#     ScrDir C:\Users\Waqar\AppData\Local\Temp\tmpvgk41uma\225a\
#     SysDir C:\GAMS\38\
#     CurDir C:\Users\Waqar\AppData\Local\Temp\tmpvgk41uma\
#     LogOption 3
# Licensee: Large MUD - 20 User License                    S220119|0002AN-GEN
#           University College London, Dep. of Chemical Engineering    DC2250
#           C:\GAMS\38\gamslice.txt
#           License Admin: Lazaros Papageorgiou, l.papageorgiou@ucl.ac.uk
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 38.2.1   Copyright (C) 1987-2022 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(122) 2 Mb
# --- Starting execution: elapsed 0:00:00.016
# --- model.gms(55) 3 Mb
# --- Generating NLP model GAMS_MODEL
# --- model.gms(56) 5 Mb
# ---   3 rows  10 columns  28 non-zeroes
# ---   3,225 nl-code  27 nl-non-zeroes
# --- model.gms(56) 3 Mb
# --- Executing SNOPT (Solvelink=5): elapsed 0:00:00.020
#
# SNOPT            38.2.1 96226ea8 Feb 19, 2022          WEI x86 64bit/MS Window
#
#
#  ==============================
#  S N O P T  7.7.7    (Feb 2021)
#  ==============================
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  Nonlinear constraints       2     Linear constraints       1
#  Nonlinear variables         9     Linear variables         0
#  Jacobian  variables         9     Objective variables      9
#  Total constraints           3     Total variables          9
#  The user has defined      18   out of      18   constraint gradients.
#  The user has defined       9   out of       9   objective  gradients.
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#      0      6               1  6.4E-01  4.9E-01 -3.1480184E-02      4           r
#      1      3  1.0E+00      2  3.7E+00  2.2E-01 -5.0977921E-01      2           r
#      2      3  1.0E+00      3  6.3E+00  9.4E-01 -9.2716780E-01      3         s
#      3      2  6.1E-01      5  3.6E+00  7.2E-02 -9.1984443E-01      4 4.8E-03
#      4      3  2.8E-01      7  2.8E+00  3.1E-01 -9.4096949E-01      4 4.8E-03
#      5      2  4.0E-01      9  1.9E+00  1.4E-01 -8.6284344E-01      4 3.0E-02
#      6      2  1.0E+00     10  3.3E-01  2.7E-01 -9.6182107E-01      5 3.0E-02
#      7      2  3.6E-01     12  3.4E-01  4.4E-01 -9.7565276E-01      4 3.0E-02
#      8      1  2.5E-01     14  2.7E-01  2.5E-01 -9.7722593E-01      4 3.0E-02
#      9      1  2.9E-01     16  2.0E-01  1.7E-01 -9.7299148E-01      4 1.6E-01
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     10      1  3.4E-01     18  1.4E-01  5.6E-02 -9.6819845E-01      4 4.4E-01
#     11      1  1.9E-01     20  1.1E-01  3.3E-02 -9.6599917E-01      4 7.2E-01
#     12      1  2.2E-01     22  8.9E-02  2.6E-02 -9.6498179E-01      4 9.3E-01
#     13      1  2.9E-01     24  6.5E-02  1.1E-02 -9.6212624E-01      4 1.8E+00
#     14      1  2.3E-01     26  5.1E-02  9.1E-03 -9.6032174E-01      4 2.7E+00
#     15      1  2.4E-01     28  4.0E-02  6.6E-03 -9.5899939E-01      4 3.9E+00
#     16      1  3.0E-01     30  2.9E-02  4.5E-03 -9.5708451E-01      4 6.7E+00
#     17      1  3.0E-01     32  2.1E-02  3.7E-03 -9.5526572E-01      4 1.2E+01
#     18      1  2.7E-01     34  1.6E-02  2.0E-03 -9.5374957E-01      4 1.9E+01
#     19      1  2.1E-01     36  1.3E-02  2.3E-03 -9.5278610E-01      4 2.7E+01
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:00.047
# --- model.gms(122) 3 Mb
# --- Putfile results C:\Users\Waqar\AppData\Local\Temp\tmpvgk41uma\results.dat
# --- Putfile statresults C:\Users\Waqar\AppData\Local\Temp\tmpvgk41uma\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 06/25/25 14:54:54 elapsed 0:00:00.050
# WARNING (W1002): Setting Var 'x[3]' to a numeric value `0.373511472553006`
# outside the bounds (0.425, 0.43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[4]' to a numeric value `0.6991896627244927`
# outside the bounds (0.595, 0.61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[5]' to a numeric value `0.7621595330739301`
# outside the bounds (0.495, 0.505).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# --- Job model.gms Start 06/25/25 14:54:54 38.2.1 96226ea8 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\38\gmsprmNT.txt
#     C:\Users\Waqar\OneDrive - University College London\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     Input C:\Users\Waqar\AppData\Local\Temp\tmpxkfw3vmm\model.gms
#     Output C:\Users\Waqar\AppData\Local\Temp\tmpxkfw3vmm\output.lst
#     ScrDir C:\Users\Waqar\AppData\Local\Temp\tmpxkfw3vmm\225a\
#     SysDir C:\GAMS\38\
#     CurDir C:\Users\Waqar\AppData\Local\Temp\tmpxkfw3vmm\
#     LogOption 3
# Licensee: Large MUD - 20 User License                    S220119|0002AN-GEN
#           University College London, Dep. of Chemical Engineering    DC2250
#           C:\GAMS\38\gamslice.txt
#           License Admin: Lazaros Papageorgiou, l.papageorgiou@ucl.ac.uk
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 38.2.1   Copyright (C) 1987-2022 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(122) 2 Mb
# --- Starting execution: elapsed 0:00:00.017
# --- model.gms(55) 3 Mb
# --- Generating NLP model GAMS_MODEL
# --- model.gms(56) 5 Mb
# ---   3 rows  10 columns  28 non-zeroes
# ---   3,225 nl-code  27 nl-non-zeroes
# --- model.gms(56) 3 Mb
# --- Executing SNOPT (Solvelink=5): elapsed 0:00:00.020
#
# SNOPT            38.2.1 96226ea8 Feb 19, 2022          WEI x86 64bit/MS Window
#
#
#  ==============================
#  S N O P T  7.7.7    (Feb 2021)
#  ==============================
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  Nonlinear constraints       2     Linear constraints       1
#  Nonlinear variables         9     Linear variables         0
#  Jacobian  variables         9     Objective variables      9
#  Total constraints           3     Total variables          9
#  The user has defined      18   out of      18   constraint gradients.
#  The user has defined       9   out of       9   objective  gradients.
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#      0      8               1  2.1E-01  4.8E-01 -4.8561922E-01      6           r
#      1      6  1.0E+00      2  3.2E+01  3.0E-01 -1.9196834E+00      3           r
#      2      5  1.0E+00      3  6.2E+00  4.2E-01 -9.8298289E-01      4 9.6E-04 s
#      3      3  2.4E-01      5  5.1E+00  8.3E-02 -8.8824713E-01      4 7.7E-03
#      4      4  4.2E-01      7  3.4E+00  2.4E-01 -9.4830125E-01      4 7.7E-03
#      5      2  2.2E-01      9  2.8E+00  1.8E-01 -8.0975851E-01      4 3.4E-02
#      6      1  1.0E+00     10  9.7E-01  4.4E-01 -8.7944184E-01      4 3.4E-02
#      7      2  4.6E-01     12  9.1E-01  1.1E-01 -9.3067115E-01      5 3.4E-02
#      8      3  4.3E-01     14  8.1E-01  1.1E-01 -9.6649973E-01      5 3.4E-02
#      9      2  4.8E-01     16  4.8E-01  2.1E-01 -9.7430873E-01      4 3.4E-02
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     40      1  2.5E-01     78  2.7E-05  4.4E-05 -9.4239421E-01      4 1.9E+05
#     41      1  2.9E-01     80  2.0E-05  3.8E-05 -9.4236513E-01      4 2.8E+05
#     42      1  3.3E-01     82  1.4E-05  3.3E-05 -9.4233571E-01      4 4.4E+05
#     43      1  3.6E-01     84  9.7E-06  2.7E-05 -9.4230829E-01      4 7.4E+05
#     44      1  3.7E-01     86  6.5E-06  2.2E-05 -9.4228314E-01      4 1.3E+06
#     45      1  3.7E-01     88  4.3E-06  1.8E-05 -9.4226272E-01      4 2.4E+06
#     46      1  3.5E-01     90  3.0E-06  1.5E-05 -9.4224610E-01      4 4.3E+06
#     47      1  3.3E-01     92  2.1E-06  1.2E-05 -9.4223374E-01      4 7.4E+06
#     48      1  3.0E-01     94  1.6E-06  1.1E-05 -9.4222453E-01      4 1.2E+07
#     49      1  2.8E-01     96  1.2E-06  9.1E-06 -9.4221806E-01      4 1.8E+07
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     50      1  2.8E-01     98 (9.1E-07) 7.8E-06 -9.4221322E-01      4 2.5E+07
#     51      1  2.9E-01    100 (6.8E-07) 6.6E-06 -9.4220958E-01      4 3.5E+07
#     52      1  3.1E-01    102 (5.0E-07) 5.5E-06 -9.4220668E-01      4 5.0E+07
#     53      1  3.5E-01    104 (3.4E-07) 4.4E-06 -9.4220447E-01      4 7.2E+07
#     54      1  3.8E-01    106 (2.3E-07) 3.4E-06 -9.4220287E-01      4 1.1E+08
#     55      1  4.3E-01    108 (1.4E-07) 2.4E-06 -9.4220189E-01      4 1.5E+08
#     56      1  1.0E+00    109 (3.2E-08)(4.0E-07)-9.4220126E-01      4 2.2E+08
#  SNOPTC EXIT   0 -- finished successfully
#  SNOPTC INFO   1 -- optimality conditions satisfied
#
#  Problem name                 GAMS_MOD
#  No. of iterations                  83   Objective           -9.4220296458E-01
#  No. of major iterations            56   Linear    obj. term  6.9410897791E-02
#  Penalty parameter           2.218E+08   Nonlinear obj. term -1.0116138624E+00
#  User function calls (total)       109
#  No. of superbasics                  4   No. of basic nonlinears             2
#  No. of degenerate steps             0   Percentage                       0.00
#  Max x                       2 1.1E+00   Max pi                      2 1.9E+05
#  Max Primal infeas          10 3.3E-08   Max Dual infeas             1 9.9E-02
#  Nonlinear constraint violn    3.3E-08
#
#  Solution not printed
#  Time for solving problem                       0.00 seconds
#  Time for constraint functions                  0.00 seconds
#  Time for objective function                    0.00 seconds
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:00.037
# --- model.gms(122) 3 Mb
# --- Putfile results C:\Users\Waqar\AppData\Local\Temp\tmpxkfw3vmm\results.dat
# --- Putfile statresults C:\Users\Waqar\AppData\Local\Temp\tmpxkfw3vmm\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 06/25/25 14:54:54 elapsed 0:00:00.040
# WARNING (W1002): Setting Var 'x[3]' to a numeric value `0.37046180656404304`
# outside the bounds (0.425, 0.43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[4]' to a numeric value `0.7368593955321927`
# outside the bounds (0.595, 0.61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[5]' to a numeric value `0.7663486883394002`
# outside the bounds (0.495, 0.505).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# --- Job model.gms Start 06/25/25 14:54:55 38.2.1 96226ea8 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\38\gmsprmNT.txt
#     C:\Users\Waqar\OneDrive - University College London\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     Input C:\Users\Waqar\AppData\Local\Temp\tmphqyybl9v\model.gms
#     Output C:\Users\Waqar\AppData\Local\Temp\tmphqyybl9v\output.lst
#     ScrDir C:\Users\Waqar\AppData\Local\Temp\tmphqyybl9v\225a\
#     SysDir C:\GAMS\38\
#     CurDir C:\Users\Waqar\AppData\Local\Temp\tmphqyybl9v\
#     LogOption 3
# Licensee: Large MUD - 20 User License                    S220119|0002AN-GEN
#           University College London, Dep. of Chemical Engineering    DC2250
#           C:\GAMS\38\gamslice.txt
#           License Admin: Lazaros Papageorgiou, l.papageorgiou@ucl.ac.uk
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 38.2.1   Copyright (C) 1987-2022 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(122) 2 Mb
# --- Starting execution: elapsed 0:00:00.023
# --- model.gms(55) 3 Mb
# --- Generating NLP model GAMS_MODEL
# --- model.gms(56) 5 Mb
# ---   3 rows  10 columns  28 non-zeroes
# ---   3,225 nl-code  27 nl-non-zeroes
# --- model.gms(56) 3 Mb
# --- Executing SNOPT (Solvelink=5): elapsed 0:00:00.028
#
# SNOPT            38.2.1 96226ea8 Feb 19, 2022          WEI x86 64bit/MS Window
#
#
#  ==============================
#  S N O P T  7.7.7    (Feb 2021)
#  ==============================
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  Nonlinear constraints       2     Linear constraints       1
#  Nonlinear variables         9     Linear variables         0
#  Jacobian  variables         9     Objective variables      9
#  Total constraints           3     Total variables          9
#  The user has defined      18   out of      18   constraint gradients.
#  The user has defined       9   out of       9   objective  gradients.
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#      0      9               1  2.1E-01  3.0E-01 -5.1573477E-01      5           r
#      1      4  1.0E+00      2  2.0E+00  5.9E-02 -8.7578608E-01      3           r
#      2      4  3.5E-01      4  2.3E+00  1.1E+00 -9.2682482E-01      5         s
#      3      4  4.6E-01      6  1.6E+00  2.9E-01 -9.3443952E-01      5 8.5E-03
#      4      3  2.6E-01      8  1.3E+00  3.4E-01 -8.7248517E-01      4 6.3E-02
#      5      2  5.6E-01     10  7.7E-01  4.7E-01 -9.0244263E-01      5 6.3E-02
#      6      2  1.0E+00     11  1.8E-01  3.4E-01 -9.6636334E-01      4 6.3E-02
#      7      1  3.7E-01     13  1.7E-01  1.7E-01 -9.7261835E-01      4 6.3E-02
#      8      1  3.2E-01     15  1.2E-01  4.8E-02 -9.7072904E-01      4 2.5E-01
#      9      1  3.7E-01     17  8.0E-02  3.3E-02 -9.6648103E-01      4 9.4E-01
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     10      1  3.6E-01     19  5.4E-02  1.4E-02 -9.6324942E-01      4 2.1E+00
#     11      1  3.4E-01     21  3.8E-02  9.6E-03 -9.6072411E-01      4 4.1E+00
#     12      1  3.2E-01     23  2.7E-02  6.0E-03 -9.5848313E-01      4 7.8E+00
#     13      1  2.7E-01     25  2.0E-02  4.5E-03 -9.5674624E-01      4 1.3E+01
#     14      1  2.1E-01     27  1.7E-02  3.6E-03 -9.5561649E-01      4 1.9E+01
#     15      1  2.2E-01     29  1.3E-02  2.9E-03 -9.5466619E-01      4 2.7E+01
#     16      1  2.5E-01     31  1.0E-02  2.6E-03 -9.5341800E-01      4 4.3E+01
#     17      1  2.3E-01     33  8.3E-03  1.6E-03 -9.5226934E-01      4 6.6E+01
#     18      1  2.1E-01     35  6.7E-03  1.7E-03 -9.5146649E-01      4 9.1E+01
#     19      1  2.1E-01     37  5.5E-03  1.2E-03 -9.5071877E-01      4 1.3E+02
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     60      1  1.0E+00    116 (3.3E-08)(5.4E-07)-9.4220129E-01      4 3.3E+08
#  SNOPTC EXIT   0 -- finished successfully
#  SNOPTC INFO   1 -- optimality conditions satisfied
#
#  Problem name                 GAMS_MOD
#  No. of iterations                  83   Objective           -9.4220358825E-01
#  No. of major iterations            60   Linear    obj. term  6.9410897791E-02
#  Penalty parameter           3.306E+08   Nonlinear obj. term -1.0116144860E+00
#  User function calls (total)       116
#  No. of superbasics                  4   No. of basic nonlinears             2
#  No. of degenerate steps             0   Percentage                       0.00
#  Max x                       2 1.1E+00   Max pi                      2 1.9E+05
#  Max Primal infeas          10 3.4E-08   Max Dual infeas             1 1.3E-01
#  Nonlinear constraint violn    3.4E-08
#
#  Solution not printed
#  Time for solving problem                       0.01 seconds
#  Time for constraint functions                  0.00 seconds
#  Time for objective function                    0.00 seconds
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:00.046
# --- model.gms(122) 3 Mb
# --- Putfile results C:\Users\Waqar\AppData\Local\Temp\tmpg5zb0li6\results.dat
# --- Putfile statresults C:\Users\Waqar\AppData\Local\Temp\tmpg5zb0li6\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 06/25/25 14:55:09 elapsed 0:00:00.049
# WARNING (W1002): Setting Var 'x[3]' to a numeric value `0.5356520476328783`
# outside the bounds (0.425, 0.43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[4]' to a numeric value `0.706745510293473`
# outside the bounds (0.595, 0.61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'x[5]' to a numeric value `0.3871281536337392`
# outside the bounds (0.495, 0.505).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# --- Job model.gms Start 06/25/25 14:55:09 38.2.1 96226ea8 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\38\gmsprmNT.txt
#     C:\Users\Waqar\OneDrive - University College London\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     Input C:\Users\Waqar\AppData\Local\Temp\tmpqetmb9rb\model.gms
#     Output C:\Users\Waqar\AppData\Local\Temp\tmpqetmb9rb\output.lst
#     ScrDir C:\Users\Waqar\AppData\Local\Temp\tmpqetmb9rb\225a\
#     SysDir C:\GAMS\38\
#     CurDir C:\Users\Waqar\AppData\Local\Temp\tmpqetmb9rb\
#     LogOption 3
# Licensee: Large MUD - 20 User License                    S220119|0002AN-GEN
#           University College London, Dep. of Chemical Engineering    DC2250
#           C:\GAMS\38\gamslice.txt
#           License Admin: Lazaros Papageorgiou, l.papageorgiou@ucl.ac.uk
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 38.2.1   Copyright (C) 1987-2022 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(122) 2 Mb
# --- Starting execution: elapsed 0:00:00.026
# --- model.gms(55) 3 Mb
# --- Generating NLP model GAMS_MODEL
# --- model.gms(56) 5 Mb
# ---   3 rows  10 columns  28 non-zeroes
# ---   3,225 nl-code  27 nl-non-zeroes
# --- model.gms(56) 3 Mb
# --- Executing SNOPT (Solvelink=5): elapsed 0:00:00.032
#
# SNOPT            38.2.1 96226ea8 Feb 19, 2022          WEI x86 64bit/MS Window
#
#
#  ==============================
#  S N O P T  7.7.7    (Feb 2021)
#  ==============================
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  Nonlinear constraints       2     Linear constraints       1
#  Nonlinear variables         9     Linear variables         0
#  Jacobian  variables         9     Objective variables      9
#  Total constraints           3     Total variables          9
#  The user has defined      18   out of      18   constraint gradients.
#  The user has defined       9   out of       9   objective  gradients.
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     70      1  2.6E-01    139  1.2E-06  1.6E-05 -9.4224163E-01      4 3.0E+07
#     71      1  2.7E-01    141 (9.5E-07) 1.4E-05 -9.4223336E-01      4 4.3E+07
#     72      1  2.7E-01    143 (7.3E-07) 1.2E-05 -9.4222606E-01      4 6.1E+07
#     73      1  2.8E-01    145 (5.6E-07) 1.0E-05 -9.4221998E-01      4 8.7E+07
#     74      1  2.9E-01    147 (4.2E-07) 8.6E-06 -9.4221481E-01      4 1.2E+08
#     75      1  3.0E-01    149 (3.1E-07) 7.2E-06 -9.4221072E-01      4 1.8E+08
#     76      1  3.0E-01    151 (2.3E-07) 6.1E-06 -9.4220744E-01      4 2.5E+08
#     77      1  3.1E-01    153 (1.7E-07) 5.0E-06 -9.4220505E-01      4 3.6E+08
#     78      1  3.2E-01    155 (1.2E-07) 4.1E-06 -9.4220332E-01      4 5.0E+08
#     79      1  3.4E-01    157 (8.8E-08) 3.2E-06 -9.4220224E-01      4 6.8E+08
#
#  Major Minors     Step   nCon Feasible  Optimal  MeritFunction     nS Penalty
#     80      1  3.5E-01    159 (6.1E-08) 2.5E-06 -9.4220160E-01      4 9.0E+08
#     81      1  3.9E-01    161 (4.1E-08)(1.8E-06)-9.4220132E-01      4 1.1E+09
#  SNOPTC EXIT   0 -- finished successfully
#  SNOPTC INFO   1 -- optimality conditions satisfied
#
#  Problem name                 GAMS_MOD
#  No. of iterations                 101   Objective           -9.4221004300E-01
#  No. of major iterations            81   Linear    obj. term  6.9410897791E-02
#  Penalty parameter           1.125E+09   Nonlinear obj. term -1.0116209408E+00
#  User function calls (total)       161
#  No. of superbasics                  4   No. of basic nonlinears             2
#  No. of degenerate steps             0   Percentage                       0.00
#  Max x                       2 1.1E+00   Max pi                      2 1.8E+05
#  Max Primal infeas          10 4.3E-08   Max Dual infeas             9 2.3E+00
#  Nonlinear constraint violn    4.3E-08
#
#  Solution not printed
#  Time for solving problem                       0.02 seconds
#  Time for constraint functions                  0.00 seconds
#  Time for objective function                    0.00 seconds
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:00.056
# --- model.gms(122) 3 Mb
# --- Putfile results C:\Users\Waqar\AppData\Local\Temp\tmpqetmb9rb\results.dat
# --- Putfile statresults C:\Users\Waqar\AppData\Local\Temp\tmpqetmb9rb\resultsstat.dat
# *** Status: Normal completion
# --- Job model.gms Stop 06/25/25 14:55:09 elapsed 0:00:00.060

# %%
scaled_value_power = power(model)()
original_value_power = scaler_input1.inverse_transform([[scaled_value_power]])[0][0]
scaled_value_thr = thr(model)()
original_value_thr = scaler_input2.inverse_transform([[scaled_value_thr]])[0][0]
scaled_value_te = te(model)()
original_value_te = scaler_input3.inverse_transform([[scaled_value_te]])[0][0]
print(f"Power: {original_value_power:.3f} MW  || Thr: {original_value_thr:.0f} kJ/kWh || Te: {original_value_te:.2f} %")
# Out:
# Power: 394.998 MW  || Thr: 8509 kJ/kWh || Te: 42.91 %

# %%
columns=['cdp', 'gffr', 'fgt', 'at', 'ap', 'ah', 'phgot', 'cdt', 'fgext']
best_values = pd.DataFrame(best_values,columns=columns)
best_values['Power_sol'] = original_value_power
best_values['THR_sol'] = original_value_thr
best_values['TE_sol'] = original_value_te

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Configuration variables
fig_size = (7, 7)  # Increased figure size
fig_dpi = 300

# Update global font properties
plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 14,  # Increased font size
    'text.color': 'black',
    'axes.labelcolor': 'black',
    'xtick.color': 'black',
    'ytick.color': 'black'
})

# Create 3D figure with more space for labels
fig = plt.figure(figsize=fig_size, dpi=fig_dpi)
ax = fig.add_subplot(111, projection='3d')

# Plot initial points (red)
ax.scatter(val['gffr'].values, 
          val['thr'].values, 
          val['te'].values, 
          color='red', edgecolor='black', 
          label='Initial Point', s=20)  # Increased marker size

# Plot solution points (green)
ax.scatter(best_values['gffr'].values, 
          best_values['THR_sol'].values, 
          best_values['TE_sol'].values, 
          color='#77DD77', edgecolor='black', 
          label='Solution', s=50)  # Increased marker size

# Connect points with lines
for n in range(len(best_values)):
    ax.plot([val['gffr'].values[n], best_values['gffr'].values[n]], 
            [val['thr'].values[n], best_values['THR_sol'].values[n]],
            [val['te'].values[n], best_values['TE_sol'].values[n]], 
            linestyle='--', alpha=0.3, color='black')  # Increased line opacity

# Set labels with increased padding
ax.set_xlabel('Gas Fuel Flow Rate (lb/s)', labelpad=10)
ax.set_ylabel('Turbine Heat Rate (kJ/kWh)', labelpad=10)
ax.set_zlabel('Thermal Efficiency (%)', labelpad=5)

# Adjust viewing angle for better visibility of all axes
ax.view_init(elev=20, azim=135)  # Modified viewing angle

# Add legend inside the plot
ax.legend(loc='upper left', bbox_to_anchor=(0.05, 0.75), fontsize=12)

# Adjust axis limits to add spacing
x_min, x_max = val['gffr'].min(), best_values['gffr'].max()
x_margin = (x_max - x_min) * 0.1  # 10% margin
ax.set_xlim(x_min - x_margin, x_max + x_margin)

# Adjust spacing between ticks
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.yaxis.set_major_locator(plt.MaxNLocator(5))
ax.zaxis.set_major_locator(plt.MaxNLocator(5))

# Adjust layout
plt.tight_layout(pad=4.0)  # Increased padding

# Save and show plot
plt.savefig('3d_scatter Solution Convergence.png', bbox_inches='tight', pad_inches=0.5)  # Added padding to saved figure
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from scipy.stats import gaussian_kde
import pandas as pd

# -------------------------------
# Configuration variables
# -------------------------------
feature_x = 'cdp'
feature_y = 'gffr'
color_map = 'YlGn'
grid_resolution = 100
fig_size = (10, 10)
fig_dpi = 300
ellipse_style = {
    'edgecolor': 'black', 
    'linestyle': '-', 
    'linewidth': 2, 
    'facecolor': 'None',
    'alpha': 1
}
tolerance = 0.95  # 95% coverage
factor = 1.0
# -------------------------------

plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 18,
    'text.color': 'black',
    'axes.labelcolor': 'black',
    'xtick.color': 'black',
    'ytick.color': 'black'
})

X = df[[feature_x, feature_y]].values

mu = np.mean(X, axis=0)
cov = np.cov(X, rowvar=False)
inv_cov = np.linalg.pinv(cov)

centered_data = X - mu
D_M = np.sqrt(np.einsum('...i,ij,...j->...', centered_data, inv_cov, centered_data))
delta = np.percentile(D_M, tolerance * 100) * factor  # <-- FIXED LINE

eigenvals, eigenvecs = np.linalg.eigh(cov)
order = eigenvals.argsort()[::-1]
eigenvals = eigenvals[order]
eigenvecs = eigenvecs[:, order]

angle = np.degrees(np.arctan2(eigenvecs[1, 0], eigenvecs[0, 0]))
width = 2 * delta * np.sqrt(eigenvals[0])
height = 2 * delta * np.sqrt(eigenvals[1])

x = df[feature_x].values
y = df[feature_y].values

kde = gaussian_kde(np.vstack([x, y]))

xmin, xmax = x.min(), x.max()
ymin, ymax = y.min(), y.max()
xgrid = np.linspace(xmin, xmax, grid_resolution)
ygrid = np.linspace(ymin, ymax, grid_resolution)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde(np.vstack([Xgrid.ravel(), Ygrid.ravel()])).reshape(Xgrid.shape)

fig, ax = plt.subplots(figsize=fig_size, dpi=fig_dpi)
cb = ax.contourf(Xgrid, Ygrid, Z, levels=25, cmap=color_map)

ellipse = Ellipse(mu, width, height, angle=angle, **ellipse_style)
ax.add_patch(ellipse)

ax.scatter(best_values[feature_x], best_values[feature_y], 
           color='#77DD77', edgecolor='black', s=100, label='Optimal Solution')

ax.scatter(
    extra[(extra['power'] < current_value + 1) & (extra['power'] > current_value - 1)][feature_x],
    extra[(extra['power'] < current_value + 1) & (extra['power'] > current_value - 1)][feature_y], 
    color="#3793AF", edgecolor='black', s=50, label='Experimental'
)

ax.set_xlabel('Compressor Discharge Pressure (Psi)', labelpad=0, fontsize=34)
ax.set_ylabel('Gas Fuel Flow rate (lb/s)', labelpad=0, fontsize=34)
ax.tick_params(axis='both', which='major', labelsize=34)  # Increase tick font size
#ax.legend(loc='upper left', fontsize=34)  # Increase legend font size

plt.savefig(f'correlated_fig_{current_value}_{tolerance}.png', bbox_inches='tight', pad_inches=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# -------------------------------
# Configuration variables
# -------------------------------
feature_x = 'cdt'
feature_y = 'phgot'
color_map = 'YlGn'  # Light, visually pleasant color map
grid_resolution = 100
num_intermediate_points = 50  # Number of points along the convergence path
fig_size = (10, 10)
fig_dpi = 300
tolerance = 0.95  # 95% coverage ellipse
ellipse_style = {'edgecolor': 'black', 'linestyle': '-', 
                'linewidth': 2, 'facecolor': 'None','alpha' :1}
# -------------------------------

# Set global font properties
plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 18,
    'text.color': 'black',
    'axes.labelcolor': 'black',
    'xtick.color': 'black',
    'ytick.color': 'black'
})

# Extract data from DataFrame
data = df[[feature_x, feature_y]].values

# Calculate statistics
mu = np.mean(data, axis=0)
cov = np.cov(data, rowvar=False)
inv_cov = np.linalg.inv(cov)

# Calculate Mahalanobis distances
centered_data = data - mu
D_M = np.sqrt(np.einsum('...i,ij,...j->...', centered_data, inv_cov, centered_data))
delta = np.percentile(D_M, tolerance * 100)

# Calculate ellipse parameters
eigenvals, eigenvecs = np.linalg.eigh(cov)
order = eigenvals.argsort()[::-1]
eigenvals, eigenvecs = eigenvals[order], eigenvecs[:, order]
angle = np.degrees(np.arctan2(*eigenvecs[:, 0][::-1]))
width, height = 2 * delta * np.sqrt(eigenvals)


x = df[feature_x]
y = df[feature_y]

# Perform Kernel Density Estimation (KDE) to estimate density distribution
kde = gaussian_kde([x, y])

# Create a high-resolution grid for evaluating the KDE
xlist = np.linspace(x.min(), x.max(), grid_resolution)
ylist = np.linspace(y.min(), y.max(), grid_resolution)
X, Y = np.meshgrid(xlist, ylist)

# Evaluate the KDE on the grid
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde(positions).T, X.shape)
# Create plot
fig, ax = plt.subplots(figsize=fig_size, dpi=fig_dpi)
cb = ax.contourf(X, Y, Z, levels=25, cmap=color_map)

# Add Mahalanobis ellipse
ax.add_patch(Ellipse(mu, width, height, angle=angle, **ellipse_style))

ax.scatter(
    extra[(extra['power'] < current_value + 1) & (extra['power'] > current_value - 1)][feature_x],
    extra[(extra['power'] < current_value + 1) & (extra['power'] > current_value - 1)][feature_y], 
    color="#3793AF", edgecolor='black', s=50, label='Experimental'
)
ax.scatter(best_values[feature_x], best_values[feature_y], 
           color='#77DD77', edgecolor='black', s=100, label='Solution')


# Configure axes and legend
ax.set_xlabel('Compressor Discharge \n Temperature (°F)', labelpad=0, fontsize=34)
ax.set_ylabel('Performance Heater Gas \n Outlet Temperature (°F)', labelpad=0, fontsize=34)
ax.tick_params(axis='both', which='major', labelsize=34)  # Increase tick font size
#ax.legend(loc='upper left')

all_x = np.concatenate([df[feature_x], 
                       val_1[feature_x], 
                       best_values[feature_x]])
all_y = np.concatenate([df[feature_y], 
                       val_1[feature_y], 
                       best_values[feature_y]])


plt.xlim(all_x.min(), all_x.max())
plt.ylim(all_y.min(), all_y.max())
plt.savefig(f'non_correlated_{current_value}_{tolerance}.png',bbox_inches='tight', pad_inches=0.3)
plt.show()

# %% [markdown]
# # Ramp up

# %%
import pandas as pd

input_labels = ['cdp', 'gffr', 'fgt', 'at', 'ap', 'ah', 'phgot', 'cdt', 'fgext']
results_all = []
power_range =range(185, 395, 15)  # Range of power setpoints from 185 to 395 with step of 20  

for power_setpoint in power_range:
    scaled_power = scaler_input1.transform([[power_setpoint]])[0][0]

    def power_constraint(model): 
        return (power(model) - scaled_power)**2 == 1e-10

    model.power_constraint = Constraint(rule=power_constraint)
    best_objective = float('inf')  # for minimization
    best_solution = {}

    best_values = []
    thr_sol = []
    power_sol = []
    TE_sol = []

    for x0 in vals[:50]:  
        initial_values = list(np.clip(x0, 0, 1))
        for i in range(x0.shape[0]):
            model.x[i] = initial_values[i]

        results = solver.solve(model, tee=False)

        optimal_scaled = [model.x[i]() for i in range(x0.shape[0])]
        optimal_real = scaler_input.inverse_transform([optimal_scaled])[0]
        scaled_value_power = power(model)()
        original_value_power = scaler_input1.inverse_transform([[scaled_value_power]])[0][0]
        scaled_value_thr = thr(model)()
        original_value_thr = scaler_input2.inverse_transform([[scaled_value_thr]])[0][0]
        scaled_value_te = te(model)()
        original_value_te = scaler_input3.inverse_transform([[scaled_value_te]])[0][0]

        # Objective value (same logic as used in Pyomo)
        objective_val = original_value_thr - original_value_te

        # ✅ Convert to dict here
        if objective_val < best_objective:
            best_objective = objective_val
            best_solution = {
                "Objective Value": best_objective,
                "Power Setpoint": power_setpoint,
                "Power": original_value_power,
                "THR": original_value_thr,
                "TE": original_value_te,
                **dict(zip(input_labels, optimal_real))
            }
    results_all.append(best_solution)
df_best = pd.DataFrame(results_all)
df_best.to_csv("mean_cond_best_local_solutions.csv", index=False)

# %% [markdown]
# # Uncertainty Assessment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Number of Monte Carlo runs
n_runs = 1000

# Choose which row (solution) to analyze, e.g., the first one
row = optimal_real

# Extract optimal input values
input_labels = ['cdp', 'gffr', 'fgt', 'at', 'ap', 'ah', 'phgot', 'cdt', 'fgext']
optimal_inputs = optimal_inputs = np.array(row).astype(float)

# Define standard deviations for each input (adjust as needed)
input_stds = np.array([0.442,	0.068,	0.179,	0.044,	0.024,	0.170,	0.030,	0.411,	0.191])  # Example stds

# Storage for outputs
outputs = []

for i in range(n_runs):
    # Perturb inputs with Gaussian noise
    perturbed_inputs = optimal_inputs + np.random.normal(0, input_stds, size=optimal_inputs.shape)
    
  
    
    # Prepare DataFrame for scaling
    perturbed_df = pd.DataFrame([perturbed_inputs], columns=input_labels)
    perturbed_scaled = scaler_input.transform(perturbed_df)

    # Optionally, clip to physical bounds
    perturbed_inputs = np.clip(perturbed_scaled, lower_bounds, upper_bounds)
    
    # Set model variables
    for j, label in enumerate(input_labels):
        model.x[j] = perturbed_scaled[0, j]
    
    # Evaluate outputs
    thr_val = thr(model)()
    power_val = power(model)()
    te_val = te(model)()
    
    # Inverse transform outputs if needed
    thr_real = scaler_input2.inverse_transform([[thr_val]])[0][0]
    power_real = scaler_input1.inverse_transform([[power_val]])[0][0]
    te_real = scaler_input3.inverse_transform([[te_val]])[0][0]
    
    outputs.append([thr_real, power_real, te_real])

outputs = np.array(outputs)
thr_vals, power_vals, te_vals = outputs[:,0], outputs[:,1], outputs[:,2]

# Plot histograms of outputs
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.hist(thr_vals, bins=30, color='skyblue')
plt.axvline(x=original_value_thr, color='black', linestyle='--', linewidth=1.5, label='Optimal')
plt.xlabel('Turbine Heat Rate (kJ/kWh)')
plt.ylabel('Frequency')

plt.subplot(1,3,2)
plt.hist(power_vals, bins=30, color='lightgreen')
plt.axvline(x=original_value_power, color='black', linestyle='--', linewidth=1.5, label='Optimal')
plt.xlabel('Power (MW)')

plt.subplot(1,3,3)
plt.hist(te_vals, bins=30, color='salmon')
plt.axvline(x=original_value_te, color='black', linestyle='--', linewidth=1.5, label='Optimal')
plt.xlabel('Thermal Efficiency (%)')
plt.tight_layout()
plt.savefig('{390}Local_sensitivity_analysis_histograms.png', dpi=300)
plt.show()

# %%
thr_mean = outputs[:,0].mean()
power_mean = outputs[:,1].mean()
te_mean = outputs[:,2].mean()

thr_std = outputs[:,0].std()
power_std = outputs[:,1].std()
te_std = outputs[:,2].std()

thr_ci = np.percentile(outputs[:,0], 97.5) - np.percentile(outputs[:,0], 2.5)
power_ci = np.percentile(outputs[:,1], 97.5) - np.percentile(outputs[:,1], 2.5)
te_ci = np.percentile(outputs[:,2], 97.5) - np.percentile(outputs[:,2], 2.5)

print(f"Mean THR: {thr_mean:.2f} | Mean Power: {power_mean:.2f} | Mean TE: {te_mean:.2f}")
print(f"Std THR: {thr_std:.2f} | Std Power: {power_std:.2f} | Std TE: {te_std:.2f}")
print(f"95% CI width THR: {thr_ci:.2f} | Power: {power_ci:.2f} | TE: {te_ci:.2f}")
